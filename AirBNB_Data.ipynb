# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
pd.set_option('display.max_rows', 500)

# %%
calendar = pd.read_csv('C:\\Users\\Danny\\Desktop\\GITHUB\\DANIELWALLACE_CAPSTONE2\\DANIELWALLACE_CAPSTONE2DATA\\calendar.csv')
calendar
# Out:
#           listing_id        date available    price adjusted_price  \
# 0              62901  2020-06-17         f   $55.00         $55.00
# 1             147244  2020-06-15         f  $149.00        $149.00
# 2             147244  2020-06-16         f  $149.00        $149.00
# 3             147244  2020-06-17         f  $149.00        $149.00
# 4             147244  2020-06-18         f  $149.00        $149.00
# ...              ...         ...       ...      ...            ...
# 30553639    43737744  2021-06-08         t   $83.00         $83.00
# 30553640    43737744  2021-06-09         t   $83.00         $83.00
# 30553641    43737744  2021-06-10         t   $83.00         $83.00
# 30553642    43737744  2021-06-11         t   $83.00         $83.00
# 30553643    43737744  2021-06-12         t   $83.00         $83.00
#
#           minimum_nights  maximum_nights
# 0                    1.0           730.0
# 1                    3.0            90.0
# ...

# %%
calendar.to_csv('calendar_c.csv')

# %%
reviews = pd.read_csv('C:\\Users\\Danny\\Desktop\\GITHUB\DANIELWALLACE_CAPSTONE2\\DANIELWALLACE_CAPSTONE2DATA\\reviews.csv')
reviews
# Out:
#          listing_id        date
# 0             11551  2010-03-21
# 1             11551  2010-03-29
# 2             11551  2010-05-09
# 3             11551  2010-06-01
# 4             11551  2010-06-28
# ...             ...         ...
# 1415073    43439400  2020-06-03
# 1415074    43440726  2020-06-07
# 1415075    43447354  2020-06-02
# 1415076    43463173  2020-06-07
# 1415077    43564804  2020-06-07
#
# [1415078 rows x 2 columns]

# %%
reviews.to_csv('reviews_c.csv')

# %%
listings = pd.read_csv('C:\\Users\\Danny\\Desktop\\GITHUB\DANIELWALLACE_CAPSTONE2\\DANIELWALLACE_CAPSTONE2DATA\\listings.csv')
listings
# Out:
#              id                                               name    host_id  \
# 0         11551         Arty and Bright London Apartment in Zone 2      43039
# 1         13913                Holiday London DB Room Let-on going      54730
# 2         15400                Bright Chelsea  Apartment. Chelsea!      60302
# 3         17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1      67564
# 4         17506  Boutique Chelsea/Fulham Double bed 5-star ensuite      67915
# ...         ...                                                ...        ...
# 83706  43747259  Room with Complete Privacy - Zone 1 Central Lo...  349591259
# 83707  43748104  Sophisticated 3 Bed Apartment Next To River Th...  175128252
# 83708  43748730   Amazing 1 Bedroom 1 Bath Apartment Safe & Secure  270804039
# 83709  43749033      King room with OWN bathroom in central London  290487366
# 83710  43751716     Double room with separate kitchen and bathroom  149258135
#
# ...

# %%
pd.set_option('display.expand_frame_repr', True)
listings['last_review'].fillna("None", inplace = True)
listings['reviews_per_month'].fillna("None", inplace = True)
listings['name'].fillna("None", inplace = True)
listings.head(100)
# Out:
#        id                                               name  host_id  \
# 0   11551         Arty and Bright London Apartment in Zone 2    43039
# 1   13913                Holiday London DB Room Let-on going    54730
# 2   15400                Bright Chelsea  Apartment. Chelsea!    60302
# 3   17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1    67564
# 4   17506  Boutique Chelsea/Fulham Double bed 5-star ensuite    67915
# 5   25123                  Clean big Room in London (Room 1)   103583
# 6   33332     Beautiful Ensuite Richmond-upon-Thames borough   144444
# 7   36299                Kew Gardens 3BR house in cul-de-sac   155938
# 8   36660                    You are GUARANTEED to love this   157884
# 9   36986  Gorgeous Victorian Flat Overlooking London Fields   159556
# 10  37384                In the footsteps of William Blake..   161459
# 11  38151                                Double room/ lounge   163634
# ...

# %%
listings.loc[listings['id'] == 36506408]
# Out:
#              id                   name    host_id  host_name  \
# 62758  36506408  Queens Court-Flat 92A  149362525  Short Let
#
#        neighbourhood_group neighbourhood  latitude  longitude  \
# 62758                  NaN   Westminster  51.51187   -0.18872
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 62758  Entire home/apt  19929               1                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 62758                NaN                              32               344

# %%
print(pd.__version__)
# Out:
# 1.0.5

# %%
pd.get_option("display.max_rows")
# Out:
# 500

# %%
listings.drop(['neighbourhood_group'], axis = 1, inplace = True)
listings
# Out:
#              id                                               name    host_id  \
# 0         11551         Arty and Bright London Apartment in Zone 2      43039
# 1         13913                Holiday London DB Room Let-on going      54730
# 2         15400                Bright Chelsea  Apartment. Chelsea!      60302
# 3         17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1      67564
# 4         17506  Boutique Chelsea/Fulham Double bed 5-star ensuite      67915
# ...         ...                                                ...        ...
# 83706  43747259  Room with Complete Privacy - Zone 1 Central Lo...  349591259
# 83707  43748104  Sophisticated 3 Bed Apartment Next To River Th...  175128252
# 83708  43748730   Amazing 1 Bedroom 1 Bath Apartment Safe & Secure  270804039
# 83709  43749033      King room with OWN bathroom in central London  290487366
# 83710  43751716     Double room with separate kitchen and bathroom  149258135
#
# ...

# %%
listings.loc[listings['id'] == 389747]
# Out:
#          id                            name  host_id host_name  \
# 522  389747  Bright Dbl/Nr/ Excellnt Transp  1949877  NokuMary
#
#      neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 522                  NaN     Southwark  51.42869   -0.08399  Private room
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 522    230               1                  0         NaN                NaN
#
#      calculated_host_listings_count  availability_365
# 522                               1               345

# %%
listings.loc[listings['room_type'] == 'Entire home/apt']
# Out:
#              id                                               name    host_id  \
# 0         11551         Arty and Bright London Apartment in Zone 2      43039
# 2         15400                Bright Chelsea  Apartment. Chelsea!      60302
# 3         17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1      67564
# 7         36299                Kew Gardens 3BR house in cul-de-sac     155938
# 9         36986  Gorgeous Victorian Flat Overlooking London Fields     159556
# ...         ...                                                ...        ...
# 83704  43745001   One bedroom, The flat designed for modern living  159681846
# 83705  43746367     Knightsbridge Chelsea Riverside Park Apartment   47362142
# 83707  43748104  Sophisticated 3 Bed Apartment Next To River Th...  175128252
# 83708  43748730   Amazing 1 Bedroom 1 Bath Apartment Safe & Secure  270804039
# 83710  43751716     Double room with separate kitchen and bathroom  149258135
#
# ...

# %%
Dagenham = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Barking and Dagenham')]
Dagenham_homes
# Out:
#              id                                               name    host_id  \
# 2823    2009513   Luxurious 3 Bed 2 Bath Apartment , Free  Parking     290846
# 6310    5358047                Barking Guesthouse Flat for 4person   27774033
# 6311    5358342                Barking Guesthouse Flat for 4person   27774033
# 8284    6891298                   Brand new 2 bed Apartment London   10313522
# 9965    7843089   4 bed flat, close to station,free wifi, sleeps 6   41325627
# ...         ...                                                ...        ...
# 81188  42884246                          Unique & Cosy Studio Flat    8325405
# 81480  42937842               Impeccable 2-Bed Cottage in Dagenham  310835509
# 82557  43233499  2 bed flat close to barking train station &par...   20508176
# 83075  43458451  1 bedroom flat 30sec walk from Barking Undergr...   69944717
# 83374  43602904                                        Ellite Home  313933445
#
# ...

# %%
Barnet_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Barnet')]
Barnet_homes
# Out:
#              id                                               name    host_id  \
# 20        41445  2 Double bed apartment in quiet area North London     180838
# 399      338198               Stylish 2 Bed Apartment with Balcony    1718539
# 752      460379                 Beautiful Family Home North London    2289099
# 938      525056                    Beautiful Family Home near Tube    2581266
# 1128     587412             Lovely 1 bed flat in Colindale/ Hendon     478692
# ...         ...                                                ...        ...
# 83364  43598756        Bright and cozy studio flat in Borehamwood.  206468268
# 83382  43604688                           Sleep under the stars!!!  348124006
# 83397  43614148           Modern living space with full\nAmenities    7562689
# 83630  43711736                   Cosy self contained living space   73203128
# 83708  43748730   Amazing 1 Bedroom 1 Bath Apartment Safe & Secure  270804039
#
# ...

# %%
Brent_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Brent')]
Brent_homes
# Out:
#              id                                               name    host_id  \
# 28        43202                 Beautiful 1 bed apt in Queens Park     188559
# 89        83308                       Luxury Queens Park Apartment     454121
# 175      178519                  Newly refurbished 2-bed apartment    1954110
# 183      186682   Beautiful Modern Bright Spacious 1-Bed Apartment     897316
# 251      255332                  Artistic flat close to Portobello    1315562
# ...         ...                                                ...        ...
# 83217  43518991   MODERN NEWLY REFURBISHED, GREAT LOCATION, ZONE 2   84065638
# 83255  43542096              Stylish Romantic Apartment, in London   34253933
# 83357  43591562  Large Stylish Modern Apartment in NW London Zo...  279098860
# 83531  43664502     Modern apartment with balcony in gated complex   27892104
# 83668  43726810           3 Bedroom family townhouse close to tube   62671696
#
# ...

# %%
Bromley_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Bromley')]
Bromley_homes
# Out:
#              id                                               name    host_id  \
# 581      405099                                The lynton boutique    2018776
# 1716     947200                  Overdale Villa Apartment Bromley     4558533
# 2285    1439449                3 Double beds detached in Beckenham    2357859
# 2426    1608341                 Cozy 1 Bedroom Crystal Palace Flat    7621037
# 3013    2216824             3 BED HOUSE 17MINS FROM CENTRAL LONDON   10486604
# ...         ...                                                ...        ...
# 81739  42992684    Welcome to Our Home, luxury, 9 miles Cen London  322107481
# 82547  43224961  London camping style, new camper, ideally located  170809471
# 82554  43229098                                   MORGAN APARTMENT  344237440
# 82724  43334934                               The Morgan Apartment  329991095
# 83288  43556558        Beautiful 2 bed flat near Centre of Bromley  111791910
#
# ...

# %%
Camden_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Camden')]
Camden_homes
# Out:
#              id                                               name    host_id  \
# 49        62218                     Spacious Upmarket Belsize Park     302657
# 64        71875    Bright Very Central 1-Bed in W1. King Bed, Wifi      67564
# 82        81211           Hampstead Home from home  in great area.     439880
# 97        87514                Gorgeous Spacious Bloomsbury Studio     352607
# 142      127652                    Contemporary central London apt     134938
# ...         ...                                                ...        ...
# 83622  43708814   The Camden Retreat - Spacious 4BDR Home + Garden   60103501
# 83655  43721247         Beautiful 2 bedroom mews flat in Fitzrovia  348556006
# 83674  43732209                          Gorgeous 2 bed in central   27834248
# 83683  43735017                 Charming garden house in Camden/KX    9961640
# 83690  43737041  One Bed Superior · Covent Garden St Martins On...  287322902
#
# ...

# %%
City_of_London_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'City of London')]
City_of_London_homes
# Out:
#              id                                               name    host_id  \
# 146      137581                I Bedroom Apartment Tower of London     471088
# 824      482178                  Great St Paul's and City location    2176101
# 1156     591549      Smart City studio, lifts, wifi, exclusive use    2919661
# 1335     673067   4 minute walk to Tower Bridge, 2 bedrooms, wifi.    2919661
# 1602     847464                Luxury flat,Zone1,2bed/2bath/Lounge    1517803
# ...         ...                                                ...        ...
# 83121  43474756                       Two Bed In Central London A2  325614755
# 83122  43474872                       Two Bed In Central London A3  325614755
# 83123  43475066                       Two Bed In Central London A4  325614755
# 83281  43553723  Great Studio. ideal for stay in the City of Lo...  347659500
# 83679  43734475      Inner City Living! 1BR Flat in Central London   22038740
#
# ...

# %%
Croydon_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Croydon')]
Croydon_homes
# Out:
#              id                                               name   host_id  \
# 44        55402                   Modern 2 Bed 2 Bath, UK, Croydon     57861
# 164      166760  Modern 1 bed flat, fast trains to central london!    794470
# 1973    1186592                 Bright & Fresh Apt in croydon- CHR   5319733
# 3372    2669410                 Flexistay Deluxe One Bed Apartment   8150858
# 4202    3552851             Hidden garden flat with 2 double rooms  17885857
# ...         ...                                                ...       ...
# 83433  43624245      Westciti Croydon Serviced Apartments Flat- 14  64578918
# 83435  43624371      Westciti Croydon Serviced Apartments Flat- 16  64578918
# 83437  43624442      Westciti Croydon Serviced Apartments Flat- 13  64578918
# 83438  43624501     Westciti Croydon Serviced Apartments Flat- 20A  64578918
# 83439  43624504     Westciti Croydon Serviced Apartments Flat- 20B  64578918
#
# ...

# %%
Ealing_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Ealing')]
Ealing_homes
# Out:
#              id                                           name    host_id  \
# 301      283569            Spacious luxury 2 bedroom apartment    1476754
# 558      395062             garden studio Ealing sleep up to 4    1908992
# 593      407529             Self contained studio, West London     958656
# 967      533972            Victorian Railway Cottage in zone 2    2624990
# 1242     611893         ZONE 2 FLAT w 3 BEDS & 2 BATH sleeps 7    2982363
# ...         ...                                            ...        ...
# 83251  43540078  Modern 2 Bed Flat in West Ealing, West London  325583325
# 83390  43607781     Luxury two bedroom flat with sunny terrace   24947244
# 83490  43647987     Luxury Flat to live in the heart of London  340252917
# 83492  43648412     Luxury Flat to stay in the heart of London  340252917
# 83671  43728409       Modern apartment in west London - Zone 2  269308503
#
#                  host_name neighbourhood  latitude  longitude  \
# ...

# %%
Enfield_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Enfield')]
Enfield_homes
# Out:
#              id                                               name    host_id  \
# 1624     875754                    3 bed house, sleeps 6, N.London    2896963
# 1647     891451                 Tranquil 1 bed garden flat, London    1271134
# 5234    4473571                                    2 bedroom house   23210611
# 5472    4662824                  North London Apartment - Edmonton   24127254
# 6065    5103290                             The Small Arms Factory   11834380
# ...         ...                                                ...        ...
# 82358  43142682                            ibis London Earls Court  343472364
# 82407  43160279  Beautiful secluded 4 bed London House with Garden  343602060
# 83195  43508997    Free parking- London/Green Lane- 4BR Apartment-  308724471
# 83662  43722682                            Lovely one bedroom flat  295958595
# 83692  43737777    Amazing chic boutique hotel style home & luxury  301642567
#
# ...

# %%
Greenwich_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Greenwich')]
Greenwich_homes
# Out:
#              id                                               name    host_id  \
# 277      270549                 Modern 2BR Apartment Greenwich 077    1409439
# 627      419786                  Kitchener House, Historic grounds    2087745
# 760      461923   My London Holiday Home - Royal Arsenal Riverside    2117678
# 816      478488     Modern 1-bed with stunning views across London    2370312
# 1416     721267    Cosy Greenwich flat with relaxing woodland view    3723373
# ...         ...                                                ...        ...
# 83010  43438750            2x Bedroom apartment - Sleeps 6x people  224930553
# 83019  43440726  Spacious 1 bed, close to the o2 Arena and the ...  314143221
# 83047  43449752  Spacious 1 bed, close to the o2 Arena and the ...   47092459
# 83571  43683610       Exceptional 3 bedroom apartment In Greenwich   38815659
# 83707  43748104  Sophisticated 3 Bed Apartment Next To River Th...  175128252
#
# ...

# %%
Hackney_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Hackney')]
Hackney_homes
# Out:
#              id                                               name    host_id  \
# 9         36986  Gorgeous Victorian Flat Overlooking London Fields     159556
# 63        70482  Fabulous Hackney flat  Victoria Park London fi...     357352
# 126      102391  Hackney Central - East London Charming House f...     535247
# 136      109299  Trendy Dalston 2BR/2BA En-Suite/Balcony/Gym/Train     261091
# 150      142117                Stylish & Bright, 1 Bed, Shoreditch     192627
# ...         ...                                                ...        ...
# 83271  43551951  Charming 1 Bed Flat in Stunning Converted Vica...  125539595
# 83302  43561726    Beautiful, bright warehouse flat, London fields    2064825
# 83325  43572467                       Chique Scandic Gem Of London  152788806
# 83340  43579870      Sunny Flat with private balcony in Shoreditch   19532465
# 83669  43727114          Huge TOP FLOOR stylish flat in Shoreditch   35219119
#
# ...

# %%
Hammersmith_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Hammersmith and Fulham')]
Hammersmith_homes
# Out:
#              id                                               name    host_id  \
# 14        38610                     CHARMING FAMILY HOME SLEEPS 10     165579
# 37        47687       Cosy Double studio in Zone 2 Hammersmith (6)     216660
# 46        56229       Cosy Double studio in Zone 2 Hammersmith (1)     216660
# 54        63948       Cosy Double studio in Zone 2 Hammersmith (4)     216660
# 68        73884       Cosy Double studio in Zone 2 Hammersmith (2)     216660
# ...         ...                                                ...        ...
# 83523  43660279   Convenient Shepherds Bush flat with outdoor deck    3560739
# 83529  43664044  Spacious Garden Flat (West Kensington Aparthotel)  348705633
# 83581  43685883   2 bedroom spacious flat with roof terrace Fulham   18729829
# 83635  43717652    London Hammersmith Apartment - Opp Tube Station   93759318
# 83643  43719998       Stunning modern Chelsea Waterfront apartment  200784731
#
# ...

# %%
Harigney_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Haringey')]
Harigney_homes
# Out:
#              id                                              name    host_id  \
# 119       98541                    Gorgeous Victorian Flat LONDON     519891
# 156      152863                  Spacious London garden apartment     735248
# 323      299735                Great Value Flat Nr Central London    1544432
# 325      300723               Stylish 3 Bed 2 Bath Apartment +Gdn    1549137
# 328      302527                Quiet and cozy garden flat  London    1557801
# ...         ...                                               ...        ...
# 83392  43611209               Split-level sunny loft with balcony   63634696
# 83533  43666600                    Manor House Studio Apartment A    3109728
# 83535  43666602                    Manor House Studio Apartment C    3109728
# 83536  43666604                    Manor House Studio Apartment B    3109728
# 83617  43707938  Arty, Plant-filled flat in quaint, boutique area  346225555
#
# ...

# %%
Harrow_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Harrow')]
Harrow_homes
# Out:
#              id                                               name    host_id  \
# 305      286675                     APARTMENT IN NORTH WEST LONDON    1491611
# 1688     925550                  Beautiful Non Smoking London Home    4979028
# 1846    1058485  3bed flat in Harrow, easy access to central Lo...    5827642
# 1976    1188639             Lovely cosy flat in Harrow on the Hill    5849721
# 5327    4556853                        London - 12 min from Euston    2296966
# ...         ...                                                ...        ...
# 82905  43412827      Luxurious 3 Person Modern Private Studio flat  314497580
# 82934  43419639  Chic Apartment in North London near Royal Air ...  305870687
# 82939  43419707    Lovely Apartment in Harrow near Northala Fields  305870687
# 82941  43419719            Modern Apartment in Harrow with Balcony  305870687
# 83148  43490424   Cream 3 Bedroom @  Pinner Hill  Pinner - HA5 3SD  189947197
#
# ...

# %%
Hillingdon_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Hillingdon')]
Hillingdon_homes
# Out:
#              id                                               name    host_id  \
# 1330     670667                   Open Plan 1 Bedroom nr Heathrow.    3398477
# 1401     713777                A stone throw away - Heathrow Homes    1419096
# 2163    1335072                2 Bedroom Garden Apartment Heathrow    7091589
# 4844    4111860    Stunning 5 bedroom house, near Heathrow airport   19826493
# 7147    6116453                   Duplex Penthouse panoramic views   31607089
# ...         ...                                                ...        ...
# 83099  43468041             Cosy Studio Uxbridge close to Heathrow   34768153
# 83186  43504953  4 bedroom 3-bathroom house-Heathrow-London-par...  133419327
# 83327  43573653                                   Studio apartment  258739164
# 83329  43574405            New One Bedroom Flat to rent in Ruislip  340626458
# 83543  43673765        2 Bed Apartment - walk to the tube station!   35796216
#
# ...

# %%
Hounslow_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Hounslow')]
Hounslow_homes
# Out:
#              id                                               name    host_id  \
# 101       89787              1 bed apt 30 mins from Windsor castle     488175
# 292      277580                      2 Bedroom  Cottage (E) London     381894
# 404      342804                  Chiswick: Luxury 2 bed maisonette    1631033
# 468      378551                 Double bedroom mezzanine apartment    1901556
# 904      515327     Comfy 2 Double Bed Garden Flat near the Thames    2538088
# ...         ...                                                ...        ...
# 82992  43433137  Cute&comfy 1 bed flat, free from 19 May by tub...  346190427
# 82993  43433328  Easy nice 1 bed flat ground floor, free 16 May W4  346190427
# 82994  43433564  Lovely loft flat, full bath, kitchen, Chiswick W4  346190427
# 83172  43502268        Luxury two bedroom two bathroom entire flat  111420740
# 83696  43739441             Cosy modern house near river. Chiswick  117250651
#
# ...

# %%
Islington_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Islington')]
Islington_homes
# Out:
#              id                                            name    host_id  \
# 80        81052              Bright spacious 2 bed in Islington     438948
# 102       89870               London Holiday Flat Let-Islington      54730
# 123       99333  Roof Garden Oasis 10 Minutes From  Kings Cross     523246
# 131      107048            A Luxury Studio Suite in Clerkenwell     259088
# 135      109226              Lovely two bedroom Islington home.     564310
# ...         ...                                             ...        ...
# 83472  43636079   Quiet Cosy Studio in the heart of East London   86604811
# 83542  43673188                  ANGEL APARTMENT great location    5375403
# 83550  43675400   Cosy 1-bedroom garden flat for 4 in Islington  348806696
# 83632  43713251  Prime Islington Townhouse with secluded garden  349200064
# 83699  43742984    15% off - Luxurious 2 BR Apartment\nHolloway  308724471
#
# ...

# %%
Kensington_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Kensington and Chelsea')]
Kensington_homes
# Out:
#              id                                               name    host_id  \
# 2         15400                Bright Chelsea  Apartment. Chelsea!      60302
# 35        46961                     ONE BEDROOM IN NEW DEVELOPMENT     194769
# 76        79571                Chelsea Studio by Kings Road London     428600
# 163      165336                      Charming Flat in Notting Hill     761400
# 173      174635                  1 bedroom in Vibrant Notting Hill     675616
# ...         ...                                                ...        ...
# 83656  43721253  Amazing 2bed/2bath top floor with rooftop terrace  348556006
# 83657  43721257           Brand new luxury 2 bedroom in Kensington  348556006
# 83673  43732025                                Kensington Hideaway    2157755
# 83676  43733142  3 Bedroom Flat @ Portobello Market-Ladbroke Grove   38477447
# 83687  43736352      Modern Kensington Chelsea Flat, 1 Min to Tube  349458512
#
# ...

# %%
Kingston_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Kingston upon Thames')]
Kingston_homes
# Out:
#              id                                               name    host_id  \
# 463      375799                Luxury apartment : London/Wimbledon    1889832
# 1479     754867  Luxury Flat in Stratton Court in Surbiton for 4/6    1794020
# 2639    1836056  Luxury Kingston on Thames Flat in Viceroy Lodg...    1794020
# 2851    2027129                  Cosy and bright Victorian cottage   10412680
# 3682    3074800                Victorian semi-detached family home   15573617
# ...         ...                                                ...        ...
# 81010  42837052                     Cosy Apartment at River Thames  304909746
# 81455  42934844    Large Victorian attick flat central to Surbiton   88269261
# 81703  42982046    Beautiful 3 Bedroom House in Chessington Surrey  189787355
# 83389  43607740     Self contained loft apartment central Kingston   89978417
# 83505  43652409                     Unique detached 1 bedroom flat  287421822
#
# ...

# %%
Lambeth_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Lambeth')]
Lambeth_homes
# Out:
#              id                                               name    host_id  \
# 0         11551         Arty and Bright London Apartment in Zone 2      43039
# 42        53245         Beautiful Victorian apartment in Stockwell     247650
# 67        73431  Two bedroom luxury Flat in Brixton with city v...     383525
# 78        80441                              5min from the Big Ben     416812
# 145      131444                1 bedroom apartment close to centre     646165
# ...         ...                                                ...        ...
# 83649  43721226       One bed, The flat designed for modern living  264864968
# 83701  43744404  Two bedrooms, The flat designed for modern living  296088521
# 83702  43744476   One bedroom, The flat designed for modern living  296088521
# 83703  43744938  Two bedrooms, The flat designed for modern living  159681846
# 83704  43745001   One bedroom, The flat designed for modern living  159681846
#
# ...

# %%
Lewisham_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Lewisham')]
Lewisham_homes
# Out:
#              id                                               name    host_id  \
# 161      158939                 Charming Garden Apartment | London     762736
# 263      264776                        Huge Four Bedroom Apartment    1389063
# 264      264777                              One Bedroom Apartment    1389063
# 265      264778            Two Bedroom Newly Refurbished Apartment    1389063
# 266      264779                  Refurbished Two Bedroom Apartment    1389063
# ...         ...                                                ...        ...
# 83463  43635719            Astonishing Studio Near Luxmore Gardens  226804666
# 83464  43635734            Astonishing Studio Near Luxmore Gardens  226804666
# 83520  43659729  Charming and Spacious Studio with Parking & Ga...  348396746
# 83549  43675348           Apartment opposite Deptford Park, London  119548520
# 83697  43739993  * Perfect 4 Bed Property in heart of Forest Hi...    3411469
#
# ...

# %%
Merton_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Merton')]
Merton_homes
# Out:
#              id                                              name    host_id  \
# 92        85111         3 bedroom house in Wimbledon with parking     465847
# 108       93263                  2 Bed 2 Bath Wimbledon Apartment     500558
# 151      143028  Entire London Town House Next 2 Tube & Wimbledon     694198
# 285      274918        Large 1 Bed apartment (A), wi-fi, sleeps 4     381894
# 287      275142                2 bed apartment,  sleeps 6, London     381894
# ...         ...                                               ...        ...
# 81946  43039601               Thirsk Road Studios by Allô Housing     988379
# 82328  43130360                  Lovely 1 Bed near British Museum  296027611
# 82356  43140069         1 bedroom flat with 4 sleeping facilities  343440476
# 82892  43409282                    Independent annex with parking   27030143
# 83230  43526077     Lovely apartment with backyard 5min from tube   71777877
#
# ...

# %%
Newham_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Newham')]
Newham_homes
# Out:
#              id                                              name    host_id  \
# 152      143568                   This one's got a gym and sauna!     598337
# 262      263822               2 Bedroom London East End Apartment    1384320
# 311      290233                 Executive House for Olypmic 2012     1506151
# 395      335867               2 Bed appt overlooking olympic park    1706248
# 405      343701                                 Bright, Cosy Flat     875652
# ...         ...                                               ...        ...
# 83347  43584405                    London ExCeL One bed apartment  263938818
# 83443  43629596  Spacious work friendly grd flr 2bed in Stratford  280607761
# 83455  43635526                 Modern Apt near Excel/Canar Wharf  347426273
# 83519  43659574               1 Bed Flat Stratford Prime location   98724400
# 83521  43659732                         Studio Flat in Manor Park   98724400
#
# ...

# %%
Redbridge_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Redbridge')]
Redbridge_homes
# Out:
#              id                                               name    host_id  \
# 450      367175                   2 bed flat, 15 mins to Stratford    1853739
# 667      432567                     Lovely apartment sleeps 2 to 4    2134315
# 670      433191  Quiet and well decorated one bedroomed garden ...    2152796
# 767      463665                         London 2 bedroom apartment     656176
# 908      517283                 3 bedroom, 3 bathroom house London    2546459
# ...         ...                                                ...        ...
# 82810  43381285                 Quiet and modern deep cleaned flat  342349515
# 83097  43467337      Brand new - 3 bed house for country weekends!  230530716
# 83174  43502952         Modern one bedroom apartment just for you!  346971852
# 83689  43737036             All furniture is very good.  Must Vew.  296962976
# 83698  43740235                      Stunning 5 bed Home in Ilford    7466577
#
# ...

# %%
Richmond_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Richmond upon Thames')]
Richmond_homes
# Out:
#              id                                               name    host_id  \
# 7         36299                Kew Gardens 3BR house in cul-de-sac     155938
# 278      270600             Patio Apartment in London (Twickenham)    1416605
# 474      380188                2 Bedroom Garden Flat near Richmond    1908027
# 980      537828  River View Flat with Free Parking & Great Loca...    2642640
# 1307     648921                  Lovely studio apartment in London    3140588
# ...         ...                                                ...        ...
# 83200  43511494       Beautiful Apartment in Leafy Putney - London    5041895
# 83317  43567555      Beautiful Victorian family home in Twickenham  124211684
# 83440  43625434    Large duplex apartment in Richmond & Kew London   24754200
# 83596  43695738      30 Seconds From The River Thames with parking  280864241
# 83661  43721808   Large 5 Double Bedroom House in East Sheen, SW14   12893058
#
# ...

# %%
Southwark_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Southwark')]
Southwark_homes
# Out:
#              id                                               name    host_id  \
# 56        65638                   Gorgeous London garden apartment     320901
# 166      168359      Stunning 2 Bed Apartment in Elephant & Castle     648725
# 296      280894  1 double-bed modern bright flat, SE1 (Borough ...    1464452
# 308      288857             London Bridge, Zipstays, Dbl/Twin beds    1500877
# 336      305573          Central London Hideaway in the trees, SE1     281951
# ...         ...                                                ...        ...
# 83368  43599606     2-bed 2-bath flat near Parliament with parking  273963876
# 83456  43635563                        Bright Skyline Rooftop Nest    1432477
# 83473  43636534                   Amazing 1 Bed Flat near Waterloo  291339461
# 83516  43659170      New 2 Bed Duplex Flat In Trendy London Bridge  119463580
# 83599  43697544           Beautiful 2 bed Victorian 1st Floor Flat    3451742
#
# ...

# %%
Sutton_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Sutton')]
Sutton_homes
# Out:
#              id                                             name    host_id  \
# 1841    1051861                           Entire home Wallington    5740164
# 2166    1336578                 Badgers Mount ..home near London    7247970
# 4260    3582451                    Spacious house near Wimbledon   18045377
# 8065    6758044                                   Nouvelle House    9063235
# 9339    7511586                    Modern house in Cheam Village   12839528
# ...         ...                                              ...        ...
# 80269  42655631             Lovely eco home London/Surrey border   13066912
# 81348  42910134  Large family home, close to Wimbledon & London.   92426545
# 82408  43160823    Normanhurst Studio in a period Victoria House  120179941
# 82606  43256219         Charming house with a garden and parking   38061837
# 83312  43564804    Spacious modern one bedroom flat with balcony   13292983
#
# ...

# %%
Towers_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Tower Hamlets')]
Towers_homes
# Out:
#              id                                               name    host_id  \
# 12        38407       Canary Wharf Apt sleeps 2 short walk to tube     164566
# 53        63864        FASCINATING ONE BEDROOM APT IN CANARY WHARF      54987
# 84        81449  Stylish Central London Flat with pool and terrace     441736
# 110       94138          Lovely east London ground floor apartment     503548
# 421      348549  Unwind on a Roof Terrace near Columbia Road Ma...    1764754
# ...         ...                                                ...        ...
# 83672  43730403      One bedroom in LD dock, 2 min to tower bridge  159681846
# 83675  43732532      Comfortable 2BR Flat in St. Katharine’s Docks   95003434
# 83680  43734653  2 Beds/2 Bath flat in Central London with car ...   68041972
# 83700  43744350      One bedroom in LD dock, 2 min to tower bridge  296088521
# 83710  43751716     Double room with separate kitchen and bathroom  149258135
#
# ...

# %%
Waltham_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Waltham Forest')]
Waltham_homes
# Out:
#              id                                               name    host_id  \
# 335      304976                 Large House with 5 Double Bedrooms    1569324
# 690      440874  London "Victorian cottage" flat - near Tube & STN     524036
# 704      444981                Studio 20min Walk from Olympic City    2123366
# 845      493965                   Modern 3 Bd Hse E4 close to city    2240892
# 940      526025                    Homely East London Accomodation    2585853
# ...         ...                                                ...        ...
# 82551  43227249          Whole flat for summer rent in Walthamstow   26282477
# 82995  43436836                                           The Doge   56279305
# 83487  43646019       Luminous & Spacious 1-BR flat in East London    2711832
# 83518  43659491                     Artist Studio Creative retreat  152726753
# 83556  43678945                                The Poppleton place   70201621
#
# ...

# %%
Wandsworth_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Wandsworth')]
Wandsworth_homes
# Out:
#              id                                               name    host_id  \
# 77        80123                  Pretty Self Contained Coach House     432648
# 361      315238                      Stylish 2 bedroom London flat    1619024
# 383      327743                  Great 1 bed flat for the Olympics    1675125
# 459      374594                     Sunny Victorian Flat in London    1749231
# 467      378407                    Lovely Garden Flat for 2 + baby    1900844
# ...         ...                                                ...        ...
# 83614  43706613  Spacious riverside apartment with private balcony   31497905
# 83642  43719884    2 Bedroom Apartment 1 minute walk to US Embassy  106879693
# 83681  43734713          Spacious riverside apartment with balcony   31497905
# 83684  43735100  Knightsbridge Chelsea Boutique Riverside Apart...   47362142
# 83705  43746367     Knightsbridge Chelsea Riverside Park Apartment   47362142
#
# ...

# %%
Westminster_homes = listings.loc[(listings['room_type'] == 'Entire home/apt') & (listings['neighbourhood'] == 'Westminster')]
Westminster_homes
# Out:
#              id                                               name    host_id  \
# 3         17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1      67564
# 33        45168                 Best Part of Town -Home from Home!     199549
# 39        51830                 Fantastic Period Flat Notting Hill     239020
# 45        55706        Amazing 2 bed 2 bath flat in central London     211108
# 59        67025  Charming Flat in Private Mews in a Great location     211108
# ...         ...                                                ...        ...
# 83667  43725144   Modern & comfortable Flat in the Heart of London   45836931
# 83682  43734785              !-!TOP-Luxury Spacious apartment3BR-*  349445208
# 83685  43735314            4 Bed Townhouse 2mins Walk to Hyde Park  279350330
# 83688  43737034      Quintessential London Mews House on Hyde Park  313081439
# 83691  43737744       Smart Bayswater studio w/ W/D, nr. Lancaster  314162972
#
# ...

# %%
Dagenham_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Barking and Dagenham')]
Dagenham_rooms
# Out:
#              id                                               name    host_id  \
# 189      198258                    Penthouse Living in East London     967537
# 339      306405                Spacious Double Room in East London    1575800
# 391      333931                    FEMALE ONLY: LARGE ROOM, SHOWER    1693107
# 398      337986               Spacious Large room in a Family Home    1717343
# 3162    2398015  Spacious room w/p.bathroom, WiFi, Parking, Hot...   11242534
# ...         ...                                                ...        ...
# 82643  43290379                      Quite en suite double bedroom   17670361
# 82717  43331363   Large double-ensuite in modern house with garden  253921039
# 83080  43459718                                   Cozy double room   19884846
# 83163  43497532  Luxurious haven in Hainault, private room- room 1  343941963
# 83602  43702562                                                NaN  268120669
#
# ...

# %%
Barnet_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Barnet')]
Barnet_rooms
# Out:
#              id                                             name    host_id  \
# 5         25123                Clean big Room in London (Room 1)     103583
# 19        41311                Clean big Room in London (Room 2)     103583
# 25        42010                         You Will Save Money Here     157884
# 31        44384              SINGLE ROOM IN A PENTHOUSE APARTMEN     194769
# 40        52940                          You will LOVE this view     157884
# ...         ...                                              ...        ...
# 81722  42987419   Spacious double bedroom with en suite bathroom  342242258
# 82853  43400068                                Business District  345823281
# 83545  43674232           One room/two bedroom/ whole  apartment  284239227
# 83665  43724308  MASSIVE STUDIO ROOM WITH DOUBLE BED AND ENSUITE  281367884
# 83693  43738876             Friendly accommodation room en-suite   33659738
#
# ...

# %%
Bexley_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Bexley')]
Bexley_rooms
# Out:
#              id                                          name    host_id  \
# 777      465781              Double room view of river thames    2277549
# 1274     626037                                  room to rent    3106937
# 1541     794928                Space in our HOME near London.    4188002
# 3688    3082748           Quiet 3BD property in leafy suburbs   15686310
# 4198    3550283                           Home Away From Home    6537722
# ...         ...                                           ...        ...
# 81187  42883828                                  BABA COTTAGE  253619978
# 81734  42992269  Modern House - off street parking and garden   47524486
# 81988  43049611          3 minutes walk to Abbey Wood station  342666863
# 82022  43057768                     Double bedroom In Welling   48488665
# 82849  43396784                                  BABA COTTAGE  253619978
#
#                 host_name neighbourhood  latitude  longitude     room_type  \
# ...

# %%
Brent_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Brent')]
Brent_rooms
# Out:
#              id                                               name    host_id  \
# 112       96052   *CENTRAL* modern and clean double room in Zone 2     448154
# 223      238897                Bright 'n' Arty RM - Super Location    1252248
# 224      239697          Kilburn Tube, Single Person, Quiet. Light    1256723
# 230      242090    Spacious Double Room Flatshare in London zone 2    1270641
# 300      282846                        double room for female only    1473649
# ...         ...                                                ...        ...
# 82635  43282244           Close to Central London. Good transport.  266916528
# 82727  43337645  Clean & Spacious private rooms off Wembley Hig...  295615217
# 83287  43556321  AMAZING DOUBLE ROOM IN NW10 Nr MIDDLESEX HOSPITAL  127635466
# 83301  43561561   Beautiful Double Bedroom in peaceful Queens Park  345177836
# 83624  43709303                                         Rent rooms  349158721
#
# ...

# %%
Bromley_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Bromley')]
Bromley_rooms
# Out:
#              id                                               name    host_id  \
# 86        81473                Lush room in Crystal Palace, London     441881
# 443      361944            Double Room for professionals incl WIFI    1829481
# 559      396100  Homestay with cosmopolitan family & small dog ...    1948774
# 661      430587                     Crystal Palace, home from home    2140668
# 717      449199                   Single loft room close to London    1948747
# ...         ...                                                ...        ...
# 79905  42573934                              London Monthly Rental  133067904
# 80461  42693497        Close to central London, two train stations  340096825
# 81057  42853155              Double Room near Airport with Parking  330642421
# 81825  43007435  Room in peaceful country cottage in heritage a...   88545241
# 83314  43565356  Private room located in South London / Large flat  311559752
#
# ...

# %%
Camden_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Camden')]
Camden_rooms
# Out:
#              id                                         name    host_id  \
# 32        45163                           Room with a garden     199530
# 36        47192                        Single Room in zone 1     212734
# 139      118805                   Theatreland Central London     599899
# 248      253668   Comfortable private double Room in centre.    1332358
# 272      266037          Central London with Stunning Views!    1395281
# ...         ...                                          ...        ...
# 83607  43706065     Spacious private room in Hampstead Heath  268334725
# 83616  43706999  Private, Charming Artist's Studio in Camden  344699308
# 83627  43710822                     Beautiful room available  349172942
# 83644  43720960        Large Private Room in Victorian House   39215308
# 83660  43721756            Lovely double room in Camden Town  349297732
#
#                                 host_name neighbourhood  latitude  longitude  \
# ...

# %%
City_of_London_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'City of London')]
City_of_London_rooms
# Out:
#              id                                               name    host_id  \
# 7475    6366595                            Room in the city centre   33176796
# 10011   7876250                Self-Contained Luxury En Suite Room   33979339
# 11474   8971725     A Private Guest  Room in Liverpool Street Area    2909440
# 14312  11071211                  Amazing  master room in the City!    5380343
# 15824  12230551                   Spare room in the City of London   65802710
# 21217  15414682              Newly refurbished ensuite double EC4V   52093846
# 21894  15858013  GIRLS ONLY - Liverpool Street, Sunshine Cosy R...   30389952
# 22750  16276053     Spacious Double Room in Zone 1 near Shoreditch     734407
# 25255  17734232      Charming en-suite double bedroom with balcony   17569629
# 25514  17861929   Spacious Double room with En-suite- Tower Bridge  122242322
# 28571  19353524  Double room in Central London, Liverpool Stree...    6431448
# ...

# %%
Croydon_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Croydon')]
Croydon_rooms
# Out:
#              id                                      name    host_id  \
# 11        38151                       Double room/ lounge     163634
# 47        56784                               1 twinroom      269609
# 79        81015                               DOUBLE ROOM     269609
# 103       90522                Luxury  Room In S.W London     490714
# 193      200713       LOVELY & COZY ROOM WITH KITCHENETTE     968464
# ...         ...                                       ...        ...
# 83124  43476835   Great Bedroom Near West Croydon Station   32951322
# 83127  43477196  DOUBLE BEDROOM NEAR WEST CROYDON STATION   32951322
# 83264  43545724         Beautiful Room in Shirley/Bromley   26356692
# 83328  43574271                            Home from home   30794057
# 83586  43688576        Room in London, near London Bridge  174228764
#
#               host_name neighbourhood  latitude  longitude     room_type  \
# ...

# %%
Ealing_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Ealing')]
Ealing_rooms
# Out:
#              id                                               name    host_id  \
# 118       98271                  Fab Double Room in Central Ealing     518852
# 153      145612         West London-W7, Hanwell (Area Ealing) Room     704495
# 250      254996                       Homely room in leafy Ealing.    1339807
# 274      269065                Cosy room 1 friendly home Ealing W7    1409580
# 297      281563                    Double Room in  Edwardian House    1467581
# ...         ...                                                ...        ...
# 83219  43521920               Massive lovely room in best location  300584625
# 83284  43555122  Spacious & cosy double room with private bathroom   46101126
# 83362  43594668                   Cozy room in the heart of London  340252917
# 83489  43647306                     Double room guest temp stay af  348537686
# 83629  43711255  En-Suite Room in Greenford with Garden + Bbq Area  349176877
#
# ...

# %%
Enfield_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Enfield')]
Enfield_rooms
# Out:
#              id                                               name    host_id  \
# 137      116268    DOUBLE RM IN LONDON(check in unavail 21-24 Feb)     586671
# 232      243093                  Stunning double room own bathroom    1271134
# 673      434666                Double bedroom+ 24 hr internet &Sky    2056768
# 1047     562148   Small double room, close Stansted Airport & City    2764375
# 1449     740520  Cockfosters, North London:  Private en-suit Do...     925632
# ...         ...                                                ...        ...
# 82885  43407985              Twin room in large North London house  176156899
# 82901  43410197                             Single room for ladies   99373161
# 82902  43410290       Beautiful parks, peaceful and pleasant area.   99373161
# 83670  43727726   Lovely double room in the heart of north london.  146097554
# 83686  43736332                 Guest room in suburban family home    7153910
#
# ...

# %%
Greenwich_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Greenwich')]
Greenwich_rooms
# Out:
#              id                                               name   host_id  \
# 275      269172                  London Greenwich Docklands Single   1410091
# 332      304161                 Lovely En-Suite Room Greenwich (A)   1349562
# 333      304162                    Lovely Single Room in Greenwich   1349562
# 350      310949                 A Modern Double Room in Greenwich.   1599044
# 543      391529                 Attractive, comfy double in Eltham   1958174
# ...         ...                                                ...       ...
# 83020  43441375          Beautiful Modern Riverside View Apartment  59701558
# 83106  43471058                           Room to let in Greenwich  88978398
# 83218  43520097                             Single room, Greenwich  17340686
# 83445  43631305  Close to central, ensuite bedroom, new refurbi...  16652600
# 83634  43714441        Single bedroom in stunning design apartment   2255879
#
# ...

# %%
Hackney_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Hackney')]
Hackney_rooms
# Out:
#              id                                               name    host_id  \
# 90        84532                Cosy Double room London, River View     462165
# 95        85582                                        Room to let     468831
# 113       96640                  Double room in lovely modern flat     512757
# 124      100326                 LGE single Victorian room, Clapton     527471
# 197      208952                                 PENDA'S MEAD HOUSE    1029332
# ...         ...                                                ...        ...
# 83486  43642728              Stunning house located in East London  105211770
# 83527  43661557                      Room in Clapton / East London  348684604
# 83618  43708048  ★Beautiful master bedroom w/ en suite and balc...   39205260
# 83628  43711072                          Small cute room in Hoxton   34646075
# 83641  43719586    Huge double room in a rooftop terraced house :)  349281466
#
# ...

# %%
Hammersmith_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Hammersmith and Fulham')]
Hammersmith_rooms
# Out:
#              id                                               name    host_id  \
# 4         17506  Boutique Chelsea/Fulham Double bed 5-star ensuite      67915
# 13        38605         SUNNY ROOM PRIVATE BATHROOM PLUS BREAKFAST     165579
# 24        42001                   A room with a view in Kensington     183658
# 26        42692                  Fabulous flat w garden and bkfst!     186510
# 27        43129                   Quiet Comfortable Room in Fulham     188138
# ...         ...                                                ...        ...
# 82744  43352076                One bed in loft very clean and tidy  235028800
# 82798  43374248            Cozy and clean place in great location.  280287877
# 83164  43498135               Lovely double room in central Fulham  195430600
# 83171  43501797                 Gorgeous Bright Room in Kensington  193956216
# 83508  43654067                WEST LONDON,ACTON VALE LONDON W3 SA  253820118
#
# ...

# %%
Haringey_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Haringey')]
Haringey_rooms
# Out:
#              id                                              name    host_id  \
# 8         36660                   You are GUARANTEED to love this     157884
# 15        38950  Room 1 Large Double Bedroom - front ground floor     167107
# 18        40228         Room 4 Cosy Double Bedroom on First Floor     167107
# 43        55133                       Results: All Love this Room     157884
# 62        69198                Spacious single room in quiet flat     345886
# ...         ...                                               ...        ...
# 83560  43680358                 Huge double room in the Warehouse  152684272
# 83568  43682887           Cozy New Studio close to Central London  335900360
# 83573  43683992  Spacious double room in lovely house with garden   35226881
# 83604  43703998   Victorian 1stfloor flat for toddler and parents   14528226
# 83695  43739391      Spacious double room close to central London  158099657
#
# ...

# %%
Harrow_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Harrow')]
Harrow_rooms
# Out:
#              id                                               name    host_id  \
# 633      421760                warm, comfy  and bright double room    2097774
# 876      505926                  Light Sunny Peaceful Space Harrow    2493978
# 930      522901   Lovely Family Home!  1 Minute from Tube Station!    2570275
# 974      536033                    Cottage in the beautiful garden    2483466
# 1312     656509                        Lovely room in a quiet area    2483466
# ...         ...                                                ...        ...
# 79548  42464463             Large Bright, Double Bedroom in Harrow    8488876
# 80471  42697979          SPACIOUS DOUBLE ROOM IN HARROW WEALDSTONE  334706623
# 81088  42857191  Spacious Private Room in a homely house in london  341270462
# 81497  42939722       Double room, house with driveway and garden.  341894864
# 81760  42994363            Lovely double bedroom in stunning  home   31994734
#
# ...

# %%
Havering_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Havering')]
Havering_rooms
# Out:
#              id                                             name    host_id  \
# 1015     550726               Paraympic Purple / Turquoise Rooms    2706724
# 1165     594569   Quiet single room with garden and house access    2701693
# 1949    1159758                 Feel like home - Enjoy your stay    4942966
# 3770    3182243                GIDEA PARK   ESSEX    SINGLE ROOM    8584509
# 4783    4056174                         Modern dbl rm & bathroom   18160693
# ...         ...                                              ...        ...
# 81265  42894131                              Super host 5 star .  127594929
# 81490  42938594                                        Queen Bed  127594929
# 81731  42989457            Luxury Space (Room) for Professionals  186954694
# 82416  43164682  Comfy and welcoming, beautiful private garden ,  261272873
# 83648  43721172                Large single room with breakfast.  349292612
#
# ...

# %%
Hillingdon_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Hillingdon')]
Hillingdon_rooms
# Out:
#              id                                               name    host_id  \
# 279      271122                Heathrow BNB - Home Away From Home!    1419096
# 324      300333                          london is waiting for you    1546859
# 342      307923   Double room no 1 near Brunel, Uxbridge, Heathrow    1584404
# 1194     601018                 next to lake/woods - london suburb    2963984
# 1399     713741                Heathrow Express A calm after storm    1419096
# ...         ...                                                ...        ...
# 82310  43128160                          Twin Room at Heathrow Inn  343177780
# 82897  43409736              Private room with Garden next to Lidl  186577165
# 83321  43570738                             Quirky en-suite studio  347837346
# 83546  43674645   Bog &cosy rooms with Living hall, Garden,Parking  348800359
# 83621  43708610  Lovely single room (not box room) \ngreat storage  281883180
#
# ...

# %%
Hounslow_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Hounslow')]
Hounslow_rooms
# Out:
#              id                                               name    host_id  \
# 6         33332     Beautiful Ensuite Richmond-upon-Thames borough     144444
# 21        41509                     Room in maisonette in chiswick     181028
# 184      189002                                  FAB CHISWICK ROOM     911280
# 276      269899                Beautiful farmhouse on the R Thames    1413291
# 387      330044                       Large Victorian ensuite room    1684191
# ...         ...                                                ...        ...
# 81698  42980922  Massive Double bedroom close to Isleworth station  187343220
# 82426  43167991            Lovely double bedroom heart of Chiswick  341932140
# 83285  43555602  Beautiful sunlit rooms+ FREE parking+ 30m to city   12708668
# 83405  43620285                      Clean and Lovely private Room  348285842
# 83537  43667699           Beautiful newly furnished double bedroom  187343220
#
# ...

# %%
Islington_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Islington')]
Islington_rooms
# Out:
#              id                                               name    host_id  \
# 1         13913                Holiday London DB Room Let-on going      54730
# 87        81635                Clerkenwell penthouse, huge terrace     443041
# 134      108562                                    stanza a londra     561772
# 180      182899                      ARCHITECT'S FLATLET ISLINGTON     497366
# 213      231692                              Cool room - Dalston -    1211430
# ...         ...                                                ...        ...
# 83459  43635642       Modern Room Near Tufnell Park Playing Fields  226804666
# 83526  43661505  Spacious Double room&Huge Garden in central Lo...   27564491
# 83539  43670306      Two bedrooms for 4 people in lovely Barnsbury   20258777
# 83620  43708602    ⌘Spacious stylish room  ✿garden square ☞central   41906950
# 83626  43710594     Nature inspired room ❀ central ❀ garden square   41906950
#
# ...

# %%
Kensington_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Kensington and Chelsea')]
Kensington_rooms
# Out:
#              id                                              name    host_id  \
# 55        64429  Portobello Road Notting hill. Exceptional value.     193586
# 122       99241                The Portobello Room - Notting Hill     522802
# 155      150900                   Double room, breathtaking views     726717
# 169      172629             Room in Kensington + private bathroom     471088
# 187      193794                     Bright single room in Chelsea     940283
# ...         ...                                               ...        ...
# 83262  43545482                              Luxury Private Rooms  118360991
# 83300  43559598  Luxury flat in kensington, double room & ensuite   58421530
# 83353  43590100   Beautiful double room kitchen lounge Kensington   36351534
# 83564  43680674          En-suite Small Double Room in Kensington   18633786
# 83565  43680740   Single Room close to Kensington Olympia, London   18633786
#
# ...

# %%
Kingston_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Kingston upon Thames')]
Kingston_rooms
# Out:
#              id                                               name    host_id  \
# 611      414862                 Cosy room - 20 min train to London    1961527
# 836      487783  TWIN / DOUBLE Room,  Central Kingston, S W London    2413601
# 1321     661917  Spacious  Double Bedroom,Cental Kingston SW Lo...    2413601
# 2046    1231996                 Large Double Room in a Family Home     151192
# 2073    1258698             Two cozy rooms, one single, one double    6556823
# ...         ...                                                ...        ...
# 82257  43113410                            Chills and free Netflix  343169074
# 82305  43123843                     Amazing Bedroom - Great Wifi +  246360166
# 82590  43247685      Clean bright nice very close to Richmond park  344386115
# 83100  43468139                  Super King bed near train station  346575078
# 83576  43684782    Independent cosy room. Straight train to London   98941106
#
# ...

# %%
Lambeth_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Lambeth')]
Lambeth_rooms
# Out:
#              id                                               name    host_id  \
# 41        53242                 Beautiful double bedroom Stockwell     247650
# 57        65908                        Lovely room in cool Brixton     322341
# 66        72913                Dbl en suite @ Oval tube Sth London     379315
# 93        85191                Maisonette in Central London Zone 1     466353
# 109       93500                 LUXURY DOUBLE ROOM CLAPHAM(ZONE 2)     501399
# ...         ...                                                ...        ...
# 83356  43591140   Londres - Chambre cosy dans appartement lumineux    6350902
# 83372  43601480                       CENTRAL MODERN APARTMENT # 2  232406237
# 83488  43646124  Affordable room 2 minutes walk to Brixton Station  309776890
# 83541  43672787  Clean Central London room available with Internet  115926236
# 83663  43723890             Spacious Double room in Crystal Palace  133715479
#
# ...

# %%
Lewisham_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Lewisham')]
Lewisham_rooms
# Out:
#              id                                               name    host_id  \
# 74        79216                2 twin beds in dble rm, Catford, UK     426378
# 105       90681                Beautiful Attic suite balcony views     491199
# 210      229684                    Bright room on park near city 7     448365
# 303      284437              Bright Guest Suite | Private Bathroom     762736
# 392      334310  Superior Boutique Comfort, Amazing Fast Transport    1703080
# ...         ...                                                ...        ...
# 83466  43635799           Stylish Room Near Margaret McMillan Park  226804666
# 83467  43635817           Stylish Room Near Margaret McMillan Park  226804666
# 83481  43639892             Double bedroom with amazing city views  177030282
# 83590  43691640  Smart 1 bedroom with shared bathrm great location  119621091
# 83678  43734053       Large, light and cosy room in Honor Oak Park   81467420
#
# ...

# %%
Merton_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Merton')]
Merton_rooms
# Out:
#              id                                               name   host_id  \
# 73        79129   Double Room 2 Miles from Wimbledon in Morden SM4    425764
# 253      255961    Beautiful double bedroom 5 minutes from station   1345766
# 320      296720                   bedroom to rent in SW17 - London   1530293
# 337      305813                 Family room with en suite bathroom   1573022
# 338      305818                   Double bedroom, private bathroom   1573022
# ...         ...                                                ...       ...
# 81959  43040937                Thirsk Road Studios by Allô Housing    988379
# 82128  43085411                     South Wimbledon Near Transport  63251607
# 82350  43139161    Double Lovely Room in Wimbledon / Colliers wood  19347854
# 82734  43345146  Quiet single room in spacious light 2 bedroom ...  27063413
# 83257  43543066      Large double room in a quiet area - Wimbledon  48553959
#
# ...

# %%
Newham_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Newham')]
Newham_rooms
# Out:
#              id                                               name    host_id  \
# 34        46511           Apartment with two large double bedrooms     208052
# 121       98776           Single room; friendly house; East London     134606
# 258      260259                 SPACIOUS DOUBLE ROOM, Gay friendly    1286929
# 309      289422                  Double Bedroom in Victorian House     862386
# 310      289802                     Single room in Victorian house     862386
# ...         ...                                                ...        ...
# 82535  43216571  Nice Bedroom on central London.\nNext to Westf...    8606823
# 82619  43265079        Big En Suite double bedroom at London Excel   21407914
# 82766  43357098                    Nice room in the Stratford area  119967765
# 82983  43429806                         Stratford - room 1 ensuite  140424307
# 83623  43709205   Single Room for rent w/ Living room/Garden/Drive  134935389
#
# ...

# %%
Redbridge_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Redbridge')]
Redbridge_rooms
# Out:
#              id                                               name    host_id  \
# 51        62898                                       Economy stay     306592
# 52        62901                       Twin Room (shared bathroom )     306592
# 61        69119                                Ensuite double room     306592
# 503      388387                     Bed & Breakfast - Double Room!    1943308
# 514      388995                               Tidy double bedroom     1946207
# ...         ...                                                ...        ...
# 83051  43450179                             The Broadway, Woodford  251632850
# 83104  43469759  Cozy Short Term Single Room (next to Central L...  296364399
# 83197  43510883                  multi cultured, safe and hip area  347025681
# 83238  43531804                                    Inglenook House  347413188
# 83633  43713448                                       Home Comfort  141011309
#
# ...

# %%
Richmond_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Richmond upon Thames')]
Richmond_rooms
# Out:
#              id                                               name   host_id  \
# 117       97974                    Large bedroom with 1 double bed    517799
# 143      127860  Double bedroom in cottage Twickenham (sleeps 1-2)    161720
# 179      182802                 Quiet Double Room - Good for walks    876774
# 491      387835           Large Dble Room TV+wifi nr NPL & College   1940607
# 501      388369                   Small Double in Leafy Teddington   1943227
# ...         ...                                                ...       ...
# 81653  42971224                   Double Bedroom in a luxury house  97296763
# 81654  42971225              Brand New House next to richmond park  97296763
# 82215  43102343  Beautiful double room overlooking Twickenham g...   2458515
# 82634  43278508  Double Room In Richmond  Enjoy Fast Fiber Inte...  21329248
# 83282  43553728         Huge double room in very quiet cul-de-sac.  43243241
#
# ...

# %%
Southwark_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Southwark')]
Southwark_rooms
# Out:
#              id                                             name    host_id  \
# 10        37384              In the footsteps of William Blake..     161459
# 16        38995         SPACIOUS ROOM IN CONTEMPORARY STYLE FLAT     167281
# 22        41712       Room with a view  zone 1  Central Bankside     182322
# 72        78892               Bright single room in family home.     424230
# 133      108529      PRIVATE APARTMENT: Light, Fresh and Central     561650
# ...         ...                                              ...        ...
# 83244  43534338         Cosy Double Bedroom In Bermondsey Zone 2   64952051
# 83403  43619533     Room on Central Cozy Flat w/ Skyline Balcony   10305177
# 83408  43620789               Single room near Elephant & Castle  168699679
# 83574  43684427  Modern flat with workspace and private bathroom   29864929
# 83709  43749033    King room with OWN bathroom in central London  290487366
#
# ...

# %%
Sutton_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Sutton')]
Sutton_rooms
# Out:
#              id                                               name    host_id  \
# 1842    1052279                 Cozy room 25 min from Victoria st.    5037537
# 2233    1389298                   Double room 25 min from Victoria    5037537
# 2444    1624107  Bright flat & great links (entire place in March)    8624773
# 2690    1880925                        Large Double Room in London    9792509
# 3130    2373150      Double bedroom for single occupancy in Sutton   12122942
# ...         ...                                                ...        ...
# 81689  42979118    Single room with pool/billiard and table tennis  147885591
# 81851  43011861   Stylish Double Rooms with Shared kitchen/Toilets  301446037
# 81910  43030046  Ensuite cozy double bed private room greatloca...  106055799
# 83269  43551185                             Rendeers and lavenders  344090261
# 83274  43552862         Double room with private shower and toilet   55718829
#
# ...

# %%
Tower_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Tower Hamlets')]
Tower_rooms
# Out:
#              id                                               name    host_id  \
# 50        62747  Beautiful huge double room in artist’s garden ...     289179
# 104       90549       Central, Luxury & Large Ensuite Canary Wharf     490830
# 125      100479                DBL rm near Trendy Shoreth\Brick La     506748
# 128      103682  Newly upgraded! 2 private rooms, bath, kitchen...     540340
# 130      106332                   Lovely large room, Bethnal Green     264345
# ...         ...                                                ...        ...
# 83609  43706132   Bright airy room in friendly central house share  201338996
# 83640  43719184  Centrally located double room with desk and ga...   52023198
# 83664  43724212        Zone 1-Lovely, bright flat available now!!!  161039880
# 83666  43724829    Single Room for GIRLS only in shared household.   76765440
# 83677  43733677  Garden Room by the Thames with view of O2 * Zo...  188699483
#
# ...

# %%
Waltham_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Waltham Forest')]
Waltham_rooms
# Out:
#              id                                               name    host_id  \
# 23        41870                      Room in relaxed family house!     182993
# 71        78606                   Peaceful Room Near Epping Forest     422362
# 254      256975            Double room in quaint East London House     280260
# 256      257413  (Website hidden by Airbnb) room in Sunny Apart...    1354561
# 289      276082                 Bright Clean Double Room-Chingford    1442674
# ...         ...                                                ...        ...
# 83191  43505909                           London Leyton attic room   50713270
# 83370  43600647                       Medium Double Room for rent!  348075162
# 83404  43619759   Friendly and bright home with lots of character.   39009349
# 83477  43638681     Cosy Room, In The Heart Of Walthamstow Village  348454966
# 83479  43639553    One double room in nice quite clean home London   75601723
#
# ...

# %%
Wandsworth_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Wandsworth')]
Wandsworth_rooms
# Out:
#              id                                               name    host_id  \
# 99        88032                    Wimbledon Luxury Home Twin Room     481587
# 106       92644                                          Twin room     498201
# 177      180449                London Battersea Light & Quiet room     864565
# 228      241621                 Bright Double room, LONDON. Zone 3    1267045
# 261      263672                  Single Room - Clapham / Battersea    1383749
# ...         ...                                                ...        ...
# 83338  43578666    Beautiful flat with view overlooking the Thames   13971349
# 83449  43632699  Big loft room with private bathroom in Southfi...    5156610
# 83532  43666286   Spacious airy double bedroom in Tooting Broadway   66612851
# 83572  43683855  Modern room with a double bed in a great location  195327381
# 83694  43739052              Wandsworth London Zone 3. Double room  293224253
#
# ...

# %%
Westminster_rooms = listings.loc[(listings['room_type'] == 'Private room') & (listings['neighbourhood'] == 'Westminster')]
Westminster_rooms
# Out:
#              id                                               name    host_id  \
# 17        39387           Stylish bedsit in Notting Hill ish flat.     168920
# 48        59656                 PASSING THROUGH Paddington LONDON?     196620
# 98        87827                ChiqDoube Room in PrivateAppartment     479209
# 172      174132                Large Bedroom with EnSuite Bathroom     831866
# 259      260288           301 Twin or Triple West End London Comfy    1365824
# ...         ...                                                ...        ...
# 83566  43681272                                                 R1  334000080
# 83567  43682061                                                 M1  334005766
# 83585  43688399      H11 Cosy Room with a Private Bathroom in Soho   48975847
# 83589  43688820     H111 Cosy Room with a Private Bathroom in Soho   48975847
# 83706  43747259  Room with Complete Privacy - Zone 1 Central Lo...  349591259
#
# ...

# %%
listings.loc[listings['room_type'] == 'Private room']
# Out:
#              id                                               name    host_id  \
# 1         13913                Holiday London DB Room Let-on going      54730
# 4         17506  Boutique Chelsea/Fulham Double bed 5-star ensuite      67915
# 5         25123                  Clean big Room in London (Room 1)     103583
# 6         33332     Beautiful Ensuite Richmond-upon-Thames borough     144444
# 8         36660                    You are GUARANTEED to love this     157884
# ...         ...                                                ...        ...
# 83693  43738876               Friendly accommodation room en-suite   33659738
# 83694  43739052              Wandsworth London Zone 3. Double room  293224253
# 83695  43739391       Spacious double room close to central London  158099657
# 83706  43747259  Room with Complete Privacy - Zone 1 Central Lo...  349591259
# 83709  43749033      King room with OWN bathroom in central London  290487366
#
# ...

# %%
listings['room_type'].values
# Out:
# array(['Entire home/apt', 'Private room', 'Entire home/apt', ...,
#        'Entire home/apt', 'Private room', 'Entire home/apt'], dtype=object)

# %%
listings.to_csv('listings_c.csv')

# %%
neighborhoods = pd.read_csv('C:\\Users\\Danny\\Desktop\\GITHUB\DANIELWALLACE_CAPSTONE2\\DANIELWALLACE_CAPSTONE2DATA\\neighborhoods.csv')
neighborhoods
# Out:
#     neighbourhood_group           neighbourhood
# 0                   NaN    Barking and Dagenham
# 1                   NaN                  Barnet
# 2                   NaN                  Bexley
# 3                   NaN                   Brent
# 4                   NaN                 Bromley
# 5                   NaN                  Camden
# 6                   NaN          City of London
# 7                   NaN                 Croydon
# 8                   NaN                  Ealing
# 9                   NaN                 Enfield
# 10                  NaN               Greenwich
# 11                  NaN                 Hackney
# 12                  NaN  Hammersmith and Fulham
# 13                  NaN                Haringey
# 14                  NaN                  Harrow
# 15                  NaN                Havering
# 16                  NaN              Hillingdon
# 17                  NaN                Hounslow
# 18                  NaN               Islington
# ...

# %%
neighborhoods.drop(['neighbourhood_group'], axis = 1)
# Out:
#              neighbourhood
# 0     Barking and Dagenham
# 1                   Barnet
# 2                   Bexley
# 3                    Brent
# 4                  Bromley
# 5                   Camden
# 6           City of London
# 7                  Croydon
# 8                   Ealing
# 9                  Enfield
# 10               Greenwich
# 11                 Hackney
# 12  Hammersmith and Fulham
# 13                Haringey
# 14                  Harrow
# 15                Havering
# 16              Hillingdon
# 17                Hounslow
# 18               Islington
# 19  Kensington and Chelsea
# 20    Kingston upon Thames
# 21                 Lambeth
# 22                Lewisham
# 23                  Merton
# 24                  Newham
# 25               Redbridge
# 26    Richmond upon Thames
# 27               Southwark
# 28                  Sutton
# 29           Tower Hamlets
# 30          Waltham Forest
# 31              Wandsworth
# 32             Westminster

# %%
neighborhoods.to_csv('neighborhoods_c.csv')
